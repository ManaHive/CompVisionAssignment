# %%
import numpy as np
import os
import pandas as pd
from PIL import Image
import cv2
from skimage.feature import local_binary_pattern

import tensorflow as tf

train_path = "training data"
test_path = "test data"

train_output = "processed training"
test_output = "processed test"

image_size = (500,500)

# %%
# Function to preprocess a single image
def preprocess_image(path, size):
    img = Image.open(path) # open image
    img = img.resize(size) # resize image
    img_array = np.array(img) # image to numpy array
    img_array = img_array / 255.0 # histogram normalization
    return img_array

# Function for data augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomZoom(0.2, 0.2),
])

# Function for image enhancement
def enhance_image(img):
    # Convert to grayscale
    gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    
    # Histogram equalization
    equalized_img = cv2.equalizeHist(gray_img)

    # Noise reduction
    denoised_img = cv2.GaussianBlur(equalized_img, (5, 5), 0)
    
    return denoised_img


# processing training images
for file in os.listdir(train_path):
    if file.endswith('.jpg'):
        img_path = os.path.join(train_path, file)
        processed_image = preprocess_image(img_path, image_size)
        
        # expanding dimensions to get a batch size of 1
        processed_image_batch = np.expand_dims(processed_image, axis=0)
        augmented_img_batch = data_augmentation(processed_image_batch, training=True)
        
        # squeezing batch and converting to uint8
        augmented_img = tf.squeeze(augmented_img_batch, axis=0).numpy()
        augmented_img = (augmented_img * 255).astype('uint8')

        # enhance image
        enhanced_img = enhance_image(augmented_img)

        output_path = os.path.join(train_output, file)
        Image.fromarray(enhanced_img).save(output_path)

# processeing test images
for file in os.listdir(test_path):
    if file.endswith('.jpg'):
        img_path = os.path.join(test_path, file)
        processed_image = preprocess_image(img_path, image_size)

        processed_image_batch = np.expand_dims(processed_image, axis=0)
        augmented_img_batch = data_augmentation(processed_image_batch, training=True)
        
        augmented_img = tf.squeeze(augmented_img_batch, axis=0).numpy()
        augmented_img = (augmented_img * 255).astype('uint8')

        enhanced_img = enhance_image(augmented_img)

        output_path = os.path.join(test_output, file)
        Image.fromarray(enhanced_img).save(output_path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 37
#      35 # expanding dimensions to get a batch size of 1
#      36 processed_image_batch = np.expand_dims(processed_image, axis=0)
# ---> 37 augmented_img_batch = data_augmentation(processed_image_batch, training=True)
#      39 # squeezing batch and converting to uint8
#      40 augmented_img = tf.squeeze(augmented_img_batch, axis=0).numpy()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py:882, in Layer.__call__(self, *args, **kwargs)
#     880         outputs = super().__call__(*args, **kwargs)
#     881 else:
# --> 882     outputs = super().__call__(*args, **kwargs)
#     883 # Change the layout for the layer output if needed.
#     884 # This is useful for relayout intermediate tensor in the model
#     885 # to achieve the optimal performance.
#     886 distribution = distribution_lib.distribution()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\ops\operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\sequential.py:209, in Sequential.call(self, inputs, training, mask)
#     207 def call(self, inputs, training=None, mask=None):
#     208     if self._functional:
# --> 209         return self._functional.call(inputs, training=training, mask=mask)
#     211     # Fallback: Just apply the layer sequence.
#     212     # This typically happens if `inputs` is a nested struct.
#     213     for layer in self.layers:
#     214         # During each iteration, `inputs` are the inputs to `layer`, and
#     215         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     216         # end of each iteration `inputs` is set to `outputs` to prepare for
#     217         # the next layer.
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\functional.py:175, in Functional.call(self, inputs, training, mask)
#     173         if mask is not None:
#     174             x._keras_mask = mask
# --> 175 outputs = self._run_through_graph(
#     176     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     177 )
#     178 return unpack_singleton(outputs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\ops\function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\functional.py:556, in operation_fn.<locals>.call(*args, **kwargs)
#     550 if (
#     551     hasattr(operation, "_call_has_training_arg")
#     552     and operation._call_has_training_arg
#     553     and training is not None
#     554 ):
#     555     kwargs["training"] = training
# --> 556 return operation(*args, **kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:49, in TFDataLayer.__call__(self, inputs, **kwargs)
#      47             self._convert_input_args = True
#      48     return outputs
# ---> 49 return super().__call__(inputs, **kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py:882, in Layer.__call__(self, *args, **kwargs)
#     880         outputs = super().__call__(*args, **kwargs)
#     881 else:
# --> 882     outputs = super().__call__(*args, **kwargs)
#     883 # Change the layout for the layer output if needed.
#     884 # This is useful for relayout intermediate tensor in the model
#     885 # to achieve the optimal performance.
#     886 distribution = distribution_lib.distribution()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\ops\operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\preprocessing\random_flip.py:87, in RandomFlip.call(self, inputs, training)
#      85 inputs = self.backend.cast(inputs, self.compute_dtype)
#      86 if training:
# ---> 87     return self._randomly_flip_inputs(inputs)
#      88 else:
#      89     return inputs
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\preprocessing\random_flip.py:71, in RandomFlip._randomly_flip_inputs(self, inputs)
#      61     flipped_outputs = self.backend.numpy.where(
#      62         self.backend.random.uniform(
#      63             shape=(batch_size, 1, 1, 1), seed=seed_generator
#    (...)
#      67         flipped_outputs,
#      68     )
#      69 if self.mode == VERTICAL or self.mode == HORIZONTAL_AND_VERTICAL:
#      70     flipped_outputs = self.backend.numpy.where(
# ---> 71         self.backend.random.uniform(
#      72             shape=(batch_size, 1, 1, 1), seed=seed_generator
#      73         )
#      74         <= 0.5,
#      75         self.backend.numpy.flip(flipped_outputs, axis=-3),
#      76         flipped_outputs,
#      77     )
#      78 if unbatched:
#      79     flipped_outputs = self.backend.numpy.squeeze(
#      80         flipped_outputs, axis=0
#      81     )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\random.py:26, in uniform(shape, minval, maxval, dtype, seed)
#      24 dtype = dtype or floatx()
#      25 seed = tf_draw_seed(seed)
# ---> 26 return tf.random.stateless_uniform(
#      27     shape=shape,
#      28     minval=tf.cast(minval, dtype),
#      29     maxval=tf.cast(maxval, dtype),
#      30     dtype=dtype,
#      31     seed=seed,
#      32 )
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\stateless_random_ops.py:402, in stateless_random_uniform(shape, seed, minval, maxval, dtype, name, alg)
#     392   result = gen_stateless_random_ops_v2.stateless_random_uniform_int_v2(
#     393       shape,
#     394       key=key,
#    (...)
#     399       name=name,
#     400   )
#     401 else:
# --> 402   key, counter, alg = random_ops_util.get_key_counter_alg(seed, alg)
#     403   rnd = gen_stateless_random_ops_v2.stateless_random_uniform_v2(
#     404       shape, key=key, counter=counter, dtype=dtype, alg=alg
#     405   )
#     406   result = math_ops.add(rnd * (maxval - minval), minval, name=name)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\random_ops_util.py:149, in get_key_counter_alg(seed, alg)
#     147   alg = Algorithm.AUTO_SELECT.value
#     148 alg = convert_alg_to_int(alg)
# --> 149 key, counter = _get_key_counter(seed, alg)
#     150 return key, counter, alg
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\random_ops_util.py:112, in _get_key_counter(seed, alg)
#      93 """Calculates the key and counter to pass to raw RNG ops.
#      94
#      95 This function calculates the key and counter that will be passed to
#    (...)
#     109   `StatelessRandomUniformV2`.
#     110 """
#     111 if alg == Algorithm.AUTO_SELECT.value:
# --> 112   key, counter = gen_stateless_random_ops_v2.stateless_random_get_key_counter(
#     113       seed
#     114   )
#     115 elif alg == Algorithm.PHILOX.value:
#     116   key, counter = _philox_scramble_seed(seed)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\gen_stateless_random_ops_v2.py:185, in stateless_random_get_key_counter(seed, name)
#     183 if tld.is_eager:
#     184   try:
# --> 185     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     186       _ctx, "StatelessRandomGetKeyCounter", name, seed)
#     187     _result = _StatelessRandomGetKeyCounterOutput._make(_result)
#     188     return _result
#
# KeyboardInterrupt:

# %%
# function for segmenting image
def segment_image(img_path):
    img = cv2.imread(img_path)

    gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    ret, bin_img = cv2.threshold(gray_img, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    sobel_x = cv2.Sobel(bin_img, cv2.CV_64F, 1, 0, ksize=3)
    sobel_y = cv2.Sobel(bin_img, cv2.CV_64F, 0, 1, ksize=3)
    sobel_combined = cv2.magnitude(sobel_x, sobel_y)

    return bin_img, sobel_combined

# function for extracting features
def extract_features(bin_img, edges):
    # Feature 1: Local Binary Pattern
    lbp = local_binary_pattern(bin_img, P=8, R=1, method="uniform")
    lbp_hist, _ = np.histogram(lbp.ravel(), bins=np.arange(0, 10), range=(0, 9))
    lbp_hist = lbp_hist.astype("float")

    # # Feature 2: Hu Moments
    moments = cv2.moments(bin_img)
    hu_moments = cv2.HuMoments(moments).flatten()

    # Feature 3 and 4: Mean and Standard Deviation of Sobel edges
    mean_val = np.mean(edges)
    std_dev_val = np.std(edges)

    # Combine all features into a single feature vector
    features = np.hstack([lbp_hist, hu_moments, mean_val, std_dev_val])

    return features

training_features_lst = []
num = 0
for file in os.listdir(train_output):
    if file.endswith('.jpg'):
        img_path = os.path.join(train_output, file)
        bin_img, edge = segment_image(img_path)

        features = extract_features(bin_img, edge)
        training_features_lst.append(features)
    num = num + 1
    if num % 200 == 0:
        print(num)

num = 0
test_features_lst = []
for file in os.listdir(test_output):
    if file.endswith('.jpg'):
        img_path = os.path.join(test_output, file)
        bin_img, edge = segment_image(img_path)

        features = extract_features(bin_img, edge)
        test_features_lst.append(features)
    num = num + 1
    if num % 200 == 0:
        print(num)
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 200
# 400
# 600
# 800
# 1000

# %%
# Convert features to a DataFrame
columns = [f'lbp_{i}' for i in range(9)]  # LBP feature names
columns += [f'hu_moment{i}' for i in range(7)] # Hu Moments
columns += ['mean_edge', 'std_dev_edge']  # Mean and std dev names

train_df = pd.DataFrame(training_features_lst, columns=columns)
test_df = pd.DataFrame(test_features_lst, columns=columns)

train_df
# Out:
#       lbp_0  lbp_1  lbp_2   lbp_3  lbp_4    lbp_5  lbp_6   lbp_7     lbp_8  \
# 0       3.0   52.0    0.0   781.0    0.0   1325.0    0.0   839.0  247000.0
# 1      20.0  326.0    0.0  3456.0    0.0   6896.0    0.0  3339.0  235963.0
# 2      10.0   63.0    0.0  1007.0    0.0   1647.0    0.0   985.0  246288.0
# 3       6.0  107.0    0.0  1308.0    0.0   4009.0    0.0  1230.0  243340.0
# 4      58.0  549.0    0.0  3718.0    0.0   7408.0    0.0  3447.0  234820.0
# ...     ...    ...    ...     ...    ...      ...    ...     ...       ...
# 2589   30.0  449.0    0.0  5908.0    0.0  10749.0    0.0  5861.0  227003.0
# 2590   78.0  941.0    0.0  8493.0    0.0  13520.0    0.0  8076.0  218892.0
# 2591   20.0  265.0    0.0  6580.0    0.0  14372.0    0.0  7053.0  221710.0
# 2592   56.0  653.0    0.0  6170.0    0.0  10470.0    0.0  5679.0  226972.0
# 2593   33.0  554.0    0.0  5814.0    0.0   9892.0    0.0  5668.0  228039.0
#
#       hu_moment0    hu_moment1    hu_moment2    hu_moment3    hu_moment4  \
# 0       0.000669  3.201483e-08  2.348844e-11  3.784496e-13 -8.891085e-25
# 1       0.000849  2.564127e-09  1.140597e-10  7.953073e-14 -1.925967e-26
# 2       0.000648  6.512954e-10  4.247212e-12  6.382182e-14 -3.139389e-26
# 3       0.001693  1.591157e-08  1.662653e-12  2.445360e-11  1.556692e-22
# 4       0.001088  4.496830e-09  5.357170e-11  7.049863e-11 -2.607757e-21
# ...          ...           ...           ...           ...           ...
# 2589    0.001272  5.088607e-08  1.495056e-11  4.185765e-12  1.176664e-23
# 2590    0.001306  4.463930e-09  2.718837e-11  1.971129e-11  3.514490e-22
# 2591    0.001453  2.697392e-08  1.182427e-11  3.125650e-11  5.458397e-22
# 2592    0.001491  6.998716e-09  2.124743e-11  2.449372e-11 -3.621635e-22
# 2593    0.001206  4.628365e-08  1.023298e-10  5.224152e-11  1.671761e-21
#
#         hu_moment5    hu_moment6   mean_edge  std_dev_edge
# 0    -4.785441e-17  6.947177e-25   18.834079    129.656612
# 1     3.498419e-18  2.387592e-25   89.703222    272.274655
# 2    -3.077280e-19 -1.088722e-26   24.528624    148.309928
# 3     2.422890e-15  8.922484e-24   31.933168    168.110947
# 4    -3.656995e-15 -3.459794e-21   97.202895    279.566519
# ...            ...           ...         ...           ...
# 2589 -5.479233e-16 -3.095125e-23  146.116914    335.373611
# 2590  6.216895e-16  2.910437e-22  203.354691    377.371966
# 2591  4.959958e-15  2.512614e-22  177.274429    364.957789
# 2592 -2.343994e-16 -4.255170e-22  150.670265    338.024983
# 2593 -4.071707e-16 -3.434388e-21  141.491783    329.801623
#
# [2594 rows x 18 columns]

# %%
# saving features to CSV
train_df.to_csv("training_features.csv", index=False)
test_df.to_csv("test_features.csv", index=False)
